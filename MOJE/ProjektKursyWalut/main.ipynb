# %%
import pandas as pd
from sqlalchemy import create_engine
import requests as res

# %%
url='https://api.nbp.pl/api/exchangerates/tables/A'

# %%
urlData=res.get(url).json()

# %%
date=urlData[0]['effectiveDate']

# %%
kursy=urlData[0]['rates']

# %%
df=pd.DataFrame(kursy)

# %%
print(df)
# Out:
#                                currency code       mid
# 0                       bat (Tajlandia)  THB  0.113000
# 1                     dolar amerykański  USD  3.668600
# 2                    dolar australijski  AUD  2.374400
# 3                       dolar Hongkongu  HKD  0.467400
# 4                      dolar kanadyjski  CAD  2.669500
# 5                   dolar nowozelandzki  NZD  2.173600
# 6                     dolar singapurski  SGD  2.852800
# 7                                  euro  EUR  4.255900
# 8                        forint (Węgry)  HUF  0.010654
# 9                     frank szwajcarski  CHF  4.566200
# 10                       funt szterling  GBP  4.919500
# 11                     hrywna (Ukraina)  UAH  0.087600
# 12                        jen (Japonia)  JPY  0.024687
# 13                        korona czeska  CZK  0.172700
# 14                        korona duńska  DKK  0.570300
# 15                     korona islandzka  ISK  0.029929
# ...

# %%
df['mid']=df['mid'].apply(lambda x: round(x,2))

# %%
df['date']=date

# %%
df
# Out:
#                                currency code   mid        date
# 0                       bat (Tajlandia)  THB  0.11  2025-07-17
# 1                     dolar amerykański  USD  3.67  2025-07-17
# 2                    dolar australijski  AUD  2.37  2025-07-17
# 3                       dolar Hongkongu  HKD  0.47  2025-07-17
# 4                      dolar kanadyjski  CAD  2.67  2025-07-17
# 5                   dolar nowozelandzki  NZD  2.17  2025-07-17
# 6                     dolar singapurski  SGD  2.85  2025-07-17
# 7                                  euro  EUR  4.26  2025-07-17
# 8                        forint (Węgry)  HUF  0.01  2025-07-17
# 9                     frank szwajcarski  CHF  4.57  2025-07-17
# 10                       funt szterling  GBP  4.92  2025-07-17
# 11                     hrywna (Ukraina)  UAH  0.09  2025-07-17
# 12                        jen (Japonia)  JPY  0.02  2025-07-17
# 13                        korona czeska  CZK  0.17  2025-07-17
# ...

# %%
engine=create_engine("postgresql://postgres:qwerty1234@localhost:5432/postgres")

# %%
pd.read_sql("select * from karta" ,engine)
# Out:
#      karta  idklienta   status  liczbapunktow
# 0     1001          1  aktywna            616
# 1     1002          2  aktywna            951
# 2     1003          3  aktywna            322
# 3     1004          4  aktywna            634
# 4     1005          5  aktywna            987
# ..     ...        ...      ...            ...
# 495   1496        496  aktywna            333
# 496   1497        497  aktywna              1
# 497   1498        498  aktywna            374
# 498   1499        499  aktywna            292
# 499   1500        500  aktywna            836
#
# [500 rows x 4 columns]

# %%
dataWBazie=pd.read_sql('select max(date) from kursy_walut',engine)

# %%
dataWBazie=str(dataWBazie['max'][0])

# %%
zBazy=pd.read_sql('select currency,code,mid,date from kursy_walut',engine)

# %%
zBazy=zBazy.set_index('currency')
zBazy=zBazy.sort_index()
df=df.set_index('currency')
df=df.sort_index()

# print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39584\2781097197.py in ?()
# ----> 1 zBazy=zBazy.set_index('currency')
#       2
#       3 zBazy=zBazy.sort_index()
#       4
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['currency'] are in the columns"

# %%
nowy=zBazy.compare(df)

# %%
print(nowy)
# Out:
#                  mid
#                 self other
# currency
# bat (Tajlandia)  1.0  0.11

# %%
for index,wiersz in nowy.iterrows():
    print(index,wiersz)
    nowy2=wiersz[('mid','self')]
    inx=index
# Out:
# bat (Tajlandia) mid  self     1.00
#      other    0.11
# Name: bat (Tajlandia), dtype: float64

# %%
print(nowy2)
print(inx)
# Out:
# 1.0
# bat (Tajlandia)

# %%
print(df.sort_values('currency'))
# Out:
#                                currency code   mid        date
# 32                            SDR (MFW)  XDR  5.00  2025-07-17
# 0                       bat (Tajlandia)  THB  0.11  2025-07-17
# 3                       dolar Hongkongu  HKD  0.47  2025-07-17
# 1                     dolar amerykański  USD  3.67  2025-07-17
# 2                    dolar australijski  AUD  2.37  2025-07-17
# 4                      dolar kanadyjski  CAD  2.67  2025-07-17
# 5                   dolar nowozelandzki  NZD  2.17  2025-07-17
# 6                     dolar singapurski  SGD  2.85  2025-07-17
# 7                                  euro  EUR  4.26  2025-07-17
# 8                        forint (Węgry)  HUF  0.01  2025-07-17
# 9                     frank szwajcarski  CHF  4.57  2025-07-17
# 10                       funt szterling  GBP  4.92  2025-07-17
# 11                     hrywna (Ukraina)  UAH  0.09  2025-07-17
# 12                        jen (Japonia)  JPY  0.02  2025-07-17
# ...

# %%
if(date>dataWBazie):
    df.to_sql(name='kursy_walut',con=engine,if_exists='append')
# Out:
# '2025-07-17'

# %%
# df['currency']
dataWBazie=pd.read_sql('select currency from kursy_walut',engine)
dataWBazie=str(dataWBazie['currency'])

# %%
if df['currency']==dataWBazie:
    print(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39584\400773292.py in ?()
# ----> 1 if df['currency']==dataWBazie:
#       2     print(1)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['currency']
# Out:
# 0                         bat (Tajlandia)
# 1                       dolar amerykański
# 2                      dolar australijski
# 3                         dolar Hongkongu
# 4                        dolar kanadyjski
# 5                     dolar nowozelandzki
# 6                       dolar singapurski
# 7                                    euro
# 8                          forint (Węgry)
# 9                       frank szwajcarski
# 10                         funt szterling
# 11                       hrywna (Ukraina)
# 12                          jen (Japonia)
# 13                          korona czeska
# 14                          korona duńska
# 15                       korona islandzka
# 16                        korona norweska
# 17                        korona szwedzka
# 18                           lej rumuński
# 19                         lew (Bułgaria)
# 20                           lira turecka
# 21                  nowy izraelski szekel
# ...

# %%
for a in dane:
    print(a)

# %%
pd.read_sql("Select * from kursy_walut",engine)
# Out:
#     index                             currency code   mid        date
# 0       0                      bat (Tajlandia)  THB  0.11  2025-07-17
# 1       1                    dolar amerykański  USD  3.67  2025-07-17
# 2       2                   dolar australijski  AUD  2.37  2025-07-17
# 3       3                      dolar Hongkongu  HKD  0.47  2025-07-17
# 4       4                     dolar kanadyjski  CAD  2.67  2025-07-17
# 5       5                  dolar nowozelandzki  NZD  2.17  2025-07-17
# 6       6                    dolar singapurski  SGD  2.85  2025-07-17
# 7       7                                 euro  EUR  4.26  2025-07-17
# 8       8                       forint (Węgry)  HUF  0.01  2025-07-17
# 9       9                    frank szwajcarski  CHF  4.57  2025-07-17
# 10     10                       funt szterling  GBP  4.92  2025-07-17
# 11     11                     hrywna (Ukraina)  UAH  0.09  2025-07-17
# ...
